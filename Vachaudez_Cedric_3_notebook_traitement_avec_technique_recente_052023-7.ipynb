# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os
from os import listdir
from os.path import exists
import time

import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
from sklearn.model_selection import train_test_split

from sklearn.cluster import KMeans
from sklearn import manifold, decomposition

from sklearn.metrics.cluster import adjusted_rand_score
from sklearn.metrics import *

# %%
import cv2

# %%
import tensorflow as tf

from tensorflow.keras.models import Model
# Utilisation d'autre chose que VGG16 car trop lent et surdimensionné pour nous
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping

# %%
import albumentations as A

# %%
from plot_keras_history import show_history, plot_history

# %% [markdown]
# # Récupération des données

# %%
path_csv = "./data/data_little_7.csv"
path_img = './data/Flipkart/Images'
path_img_little = './data/Flipkart/ImagesLittles'

# %%
data = pd.read_csv(path_csv)

# %%
nb_cat = len(data['cat'].unique())

# %%
input_shape = MobileNetV2().input_shape

# %% [markdown]
# # Data Augmentation

# %%
def cat_to_label(l):
    return np.argmax(l)

# %%
# Représentation des vecteurs et catégories en 2D
def show_representation(data, cat, limit=None, X_tsne=None, title=''):
    if X_tsne is None:
        tsne = manifold.TSNE(n_components=2, perplexity=30, n_iter=2000, init='random')
        X_tsne = tsne.fit_transform(data)
    
    df_tsne = pd.DataFrame(X_tsne, columns=['tsne1', 'tsne2'])
    df_tsne["class"] = cat.reset_index(drop=True)
    
    plt.figure(figsize=(8,5))
    sns.scatterplot(
        x="tsne1", y="tsne2",
        hue="class",
        palette=sns.color_palette('tab10', n_colors=nb_cat_little), s=50,
        data=df_tsne,
        legend="brief")

    plt.title(title, fontsize = 14, pad = 35, fontweight = 'bold')
    plt.xlabel('tsne1', fontsize = 14, fontweight = 'bold')
    plt.ylabel('tsne2', fontsize = 14, fontweight = 'bold')
    plt.legend(prop={'size': 8}) 

    plt.show()
    
    return X_tsne

# %% [markdown]
# ## Quelques tests de manipulation d'images

# %%
def show_from_cv2(img):
    plt.figure(figsize=(6, 6))
    
    plt.imshow(img)
    
    ax = plt.gca()
    plt.axis("off")
    return plt.show()

# %%
def visualize(original, augmented):
    fig = plt.figure()
    plt.subplot(1,2,1)
    plt.title('Original image')
    plt.imshow(original)
    plt.axis("off")
 
    plt.subplot(1,2,2)
    plt.title('Augmented image')
    plt.imshow(augmented)
    plt.axis("off")

# %% [markdown]
# ### Tests avec OpenCV

# %%
path = data['img'].iloc[0]

# %%
img = cv2.imread(path)
img = cv2.resize(img, dsize=(1000, 1000), interpolation=cv2.INTER_CUBIC)
show_from_cv2(img)

# %%
flipped = tf.image.flip_left_right(img)
visualize(img, flipped)

# %%
saturated = tf.image.adjust_saturation(img, 256)
visualize(img, saturated)

# %%
tmp = tf.image.adjust_brightness(img, 0)
visualize(img, tmp)

# %%
tmp = tf.image.adjust_contrast(img, 1)
visualize(img, tmp)

# %%
tmp = tf.image.adjust_hue(img, -0.1)
visualize(img, tmp)

# %%
bright = tf.image.stateless_random_hue(img, 0.1, (0, 0))
visualize(img, bright)

# %%
bright = tf.image.stateless_random_contrast(img, 1, 1.1, (0, 2))
visualize(img, bright)

# %% [markdown]
# ### Test avec Albumentations

# %%
transform = A.Compose([
    A.RandomSizedCrop(min_max_height=(input_shape[1]//2, input_shape[1]),
                      height=input_shape[1],
                      width=input_shape[2],
                      w2h_ratio=1.0,
                      interpolation=4,
                      p=0.5),
    A.HorizontalFlip(p=0.5),
    #A.RandomRotate90(),
    #A.Transpose(p=0.5),
    A.ShiftScaleRotate(
        shift_limit=0.02,
        scale_limit=[-0.2, 0.02],
        rotate_limit=0,
        interpolation=cv2.INTER_LANCZOS4,
        border_mode=cv2.BORDER_REFLECT_101,
        value=(255, 255, 255),
        p=0),
    A.Perspective(scale=(0.05, 0.1),
                keep_size=1,
                pad_mode=cv2.BORDER_REFLECT_101,
                pad_val=(255, 255, 255),
                fit_output=0,
                interpolation=cv2.INTER_LANCZOS4,
                p=0),
    A.SafeRotate(
        limit=10,
        interpolation=cv2.INTER_LANCZOS4,
        border_mode=cv2.BORDER_REFLECT_101,
        value=(255, 255, 255),
        p=0),
    #A.RandomBrightnessContrast(p=.75),
    A.ColorJitter(
        brightness=0.1,
        contrast=0.2,
        saturation=0.2,
        hue=0.3,
        p=0),
    #A.Blur(blur_limit=1),
    A.GaussNoise(var_limit=(5.0, 50.0), p=0.5),
    A.Downscale(p=0.75, scale_min=0.5, scale_max=0.7, interpolation=cv2.INTER_AREA)
], p=1)

# %%
transform = A.Compose([
    A.RandomRotate90(p=0.5),
    A.Flip(p=0.5),
    A.HorizontalFlip(p=0.5),
], p=1)

# %%
fig, ax = plt.subplots(5, 3, figsize=(9, 15))
for i in range(15):
    image = load_img(data['img'].iloc[i], target_size=input_shape[1:3], interpolation='lanczos')
    image = np.array(image)
    transformed = transform(image=image)
    ax[i // 3, i % 3].imshow(transformed["image"])
plt.show()

# %% [markdown]
# ## Augmentation

# %%
# Conversion des images aux bonnes dimensions et format 
def preprocess_image(path):
    image = load_img(path, target_size=input_shape[1:3], interpolation='lanczos')
    image = np.array(image)
    image = preprocess_input(image)
    return image

# %%
def preprocess_image_augmented(path):
    global transform
    image = load_img(path, target_size=input_shape[1:3], interpolation='lanczos')
    image = np.array(image)
    image = transform(image=image)['image']
    image = preprocess_input(image)
    return image

# %%
X_train_img, X_test_img, y_train_label, y_test_label = train_test_split(
    data['img'],
    data['label'],
    test_size=0.33,
    stratify=data['label'],
    random_state=43)

# %% [markdown]
# ### Génération du set de test indépendamment du reste
# pour être sûr qu'il n'y ai pas de fuite de données

# %%
X_test = list(X_test_img.apply(preprocess_image))
X_test = np.asarray(X_test).astype(np.float32)

# %%
y_test = to_categorical(y_test_label, num_classes=nb_cat)

# %% [markdown]
# ### Génération des données d'entrainement

# %% [markdown]
# #### Remplissage des catégories les plus vides pour les équilibrer

# %%
df = pd.DataFrame([X_train_img, y_train_label]).T

# %%
df['label'].value_counts()
# Out:
# label
# 2    101
# 3    101
# 5    101
# 1    100
# 6    100
# 4    100
# 0    100
# Name: count, dtype: int64

# %%
X_augmented = []
y_augmented = []

but = int(np.quantile(df['label'].value_counts().to_list(), 0.8))
ajout = but//2

print("Nombre minimum d'images dans une classe :", but)
print("Puis ajout de {} images supplémentaires dans toutes les classes.".format(ajout))
print()

for i, n in df['label'].value_counts().items():
    if n >= but:
        a_faire = 0
    else:
        a_faire = max(0, but - n)
    
    
    a_faire += ajout
    print("La classe {} passe de {} images à {}".format(i, n, n+a_faire))
    liste_images = df.loc[df['label']==i, 'img']
    for path in np.random.choice(liste_images, a_faire):
        img_tmp = preprocess_image_augmented(path)
        X_augmented.append(img_tmp)
        y_augmented.append(i)

X_augmented = np.asarray(X_augmented).astype(np.float32)
# Out:
# Nombre minimum d'images dans une classe : 101
# Puis ajout de 50 images supplémentaires dans toutes les classes.
#
# La classe 2 passe de 101 images à 151
# La classe 3 passe de 101 images à 151
# La classe 5 passe de 101 images à 151
# La classe 1 passe de 100 images à 151
# La classe 6 passe de 100 images à 151
# La classe 4 passe de 100 images à 151
# La classe 0 passe de 100 images à 151

# %%
if len(X_augmented) == 0:
    X_augmented = np.ndarray((0,) + input_shape[1:])

# %% [markdown]
# #### Ajout n fois du tout le dataset en version augmenté

# %%
for i in range(0):
    X_tmp = df["img"].apply(preprocess_image_augmented)
    X_tmp = np.asarray(list(X_tmp)).astype(np.float32)
    
    X_augmented = np.concatenate((X_augmented, X_tmp))
    
    y_tmp = df["label"].copy()
    
    y_augmented = np.concatenate((y_augmented, y_tmp))

# %% [markdown]
# #### Génération du dataset d'entrainement de base

# %%
X_train = df["img"].apply(preprocess_image)

# %%
X_train = np.asarray(list(X_train)).astype(np.float32)

# %% [markdown]
# #### Ajout des données augmentées

# %%
print("Taille d'origine du dataset d'entrainement : ", X_train.shape[0])
# Out:
# Taille d'origine du dataset d'entrainement :  703

# %%
X_train = np.concatenate((X_train, X_augmented))

# %%
print("Taille du dataset d'entrainement augmenté : ", X_train.shape[0])
# Out:
# Taille du dataset d'entrainement augmenté :  1057

# %% [markdown]
# #### Même chose pour les targets

# %%
y_train = np.concatenate((df["label"], y_augmented))

# %%
y_train = to_categorical(y_train, num_classes=nb_cat)

# %% [markdown]
# # Classification

# %% [markdown]
# ## Création du modèle et entrainement

# %%
base_model = MobileNetV2(include_top=False, input_shape=input_shape[1:])
base_model.trainable = False

# %%
flatten_layer = layers.Flatten()
dense_layer_1 = layers.Dense(nb_cat*10, activation='relu')
drop_out = layers.Dropout(0.3)
dense_layer_2 = layers.Dense(nb_cat*4, activation='relu')
prediction_layer = layers.Dense(nb_cat, activation='softmax')


model = models.Sequential([
    base_model,
    flatten_layer,
    dense_layer_1,
    drop_out,
    dense_layer_2,
    prediction_layer
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)


es = EarlyStopping(monitor='val_accuracy',  min_delta = 0.002, mode='max', patience=6, restore_best_weights=True)
#es = EarlyStopping(monitor='val_loss', min_delta = 0.002, mode='min', patience=6, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=40, validation_split=0.4, batch_size=64, callbacks=[es])
# Out:
# Epoch 1/40
# 10/10 [==============================] - 29s 3s/step - loss: 2.3325 - accuracy: 0.4700 - val_loss: 0.9385 - val_accuracy: 0.7518
# Epoch 2/40
# 10/10 [==============================] - 26s 3s/step - loss: 1.0133 - accuracy: 0.7429 - val_loss: 0.7374 - val_accuracy: 0.7612
# Epoch 3/40
# 10/10 [==============================] - 26s 3s/step - loss: 0.7930 - accuracy: 0.7855 - val_loss: 0.6399 - val_accuracy: 0.7400
# Epoch 4/40
# 10/10 [==============================] - 26s 3s/step - loss: 0.5005 - accuracy: 0.8502 - val_loss: 0.6681 - val_accuracy: 0.7707
# Epoch 5/40
# 10/10 [==============================] - 26s 3s/step - loss: 0.4767 - accuracy: 0.8644 - val_loss: 0.6064 - val_accuracy: 0.7778
# Epoch 6/40
# 10/10 [==============================] - 26s 3s/step - loss: 0.3678 - accuracy: 0.8738 - val_loss: 0.5230 - val_accuracy: 0.8109
# Epoch 7/40
# 10/10 [==============================] - 26s 3s/step - loss: 0.3187 - accuracy: 0.9038 - val_loss: 0.4484 - val_accuracy: 0.8487
# Epoch 8/40
# 10/10 [==============================] - 26s 3s/step - loss: 0.3412 - accuracy: 0.9054 - val_loss: 0.5205 - val_accuracy: 0.8416
# Epoch 9/40
# 10/10 [==============================] - 26s 3s/step - loss: 0.2529 - accuracy: 0.9306 - val_loss: 0.6731 - val_accuracy: 0.8132
# Epoch 10/40
# 10/10 [==============================] - 26s 3s/step - loss: 0.3171 - accuracy: 0.9085 - val_loss: 0.7166 - val_accuracy: 0.8203
# Epoch 11/40
# 10/10 [==============================] - 27s 3s/step - loss: 0.2730 - accuracy: 0.9227 - val_loss: 0.5241 - val_accuracy: 0.8322
# Epoch 12/40
# 10/10 [==============================] - 26s 3s/step - loss: 0.2141 - accuracy: 0.9338 - val_loss: 0.5737 - val_accuracy: 0.8156
# Epoch 13/40
# 10/10 [==============================] - 27s 3s/step - loss: 0.2184 - accuracy: 0.9259 - val_loss: 0.7495 - val_accuracy: 0.8392

# %% [markdown]
# ## Résultats

# %%
start = time.time()
pred_test = model.predict(X_test)
enlapsed = time.time() - start

print()
print("Temps de prédiction (en s): ", round(enlapsed, 2))
print("Nombre de valeurs à prédire : ", len(X_test))
print("Temps moyen par prédiction (en ms): ", int(1000 * enlapsed/len(X_test)))
# Out:
# 11/11 [==============================] - 9s 783ms/step
#
# Temps de prédiction (en s):  9.51
# Nombre de valeurs à prédire :  347
# Temps moyen par prédiction (en ms):  27

# %%
y_test_label = [cat_to_label(e) for e in y_test]
pred_test_label = [cat_to_label(e) for e in pred_test]

# %%
print("Accuracy score (taux de classes correctements prédites) sur le set de test :")
accuracy_score(y_test_label, pred_test_label)
# Out:
# Accuracy score (taux de classes correctements prédites) sur le set de test :
# 0.8069164265129684

# %%
#print("Accuracy score (taux de classes présentes dans le top 2) sur le set de test :")
#top_k_accuracy_score(y_test_label, pred_test, k=2)

# %%
print("Score de Cohen kappa sur le set de test :")
cohen_kappa_score(y_test_label, pred_test_label)
# Out:
# Score de Cohen kappa sur le set de test :
# 0.774721175182411

# %%
print("Coefficient de corrélation de Matthews sur le set de test :")
matthews_corrcoef(y_test_label, pred_test_label)
# Out:
# Coefficient de corrélation de Matthews sur le set de test :
# 0.7755934915669522

# %%
RocCurveDisplay.from_predictions(
    y_test.ravel(),
    pred_test.ravel(),
    name="micro-average OvR",
    color="darkorange",
)
plt.plot([0, 1], [0, 1], "k--", label="chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Micro-averaged One-vs-Rest\nReceiver Operating Characteristic")
plt.legend()
plt.show()

# %% [markdown]
# Résultats au cas pas cas

# %%
labels_little = data.sort_values('label')['cat'].drop_duplicates().to_list()

# %%
print(classification_report(
    [cat_to_label(e) for e in y_test],
    [cat_to_label(e) for e in pred_test],
    target_names=labels_little,
    zero_division=0))
# Out:
#                             precision    recall  f1-score   support
#
#            Home Furnishing       0.74      0.78      0.76        50
#                  Baby Care       0.67      0.72      0.69        50
#                    Watches       0.94      1.00      0.97        49
# Home Decor & Festive Needs       0.83      0.61      0.71        49
#           Kitchen & Dining       0.86      0.86      0.86        50
#   Beauty and Personal Care       0.78      0.86      0.82        49
#                  Computers       0.85      0.82      0.84        50
#
#                   accuracy                           0.81       347
#                  macro avg       0.81      0.81      0.81       347
#               weighted avg       0.81      0.81      0.81       347

# %% [markdown]
# Evolution de l'apprentissage

# %%
show_history(history)
plt.close()

# %%
def get_max_coord(data):
    max_value = data.values.max()
    return list(zip(*np.where(data.values == max_value)))[0]

# %%
def compare_clustering(original, predict, return_cat=False):
    data_show = pd.DataFrame(original, columns=['cat'])
    data_show['pred'] = predict
    data_show = pd.get_dummies(data_show, columns=['pred'])
    data_show = data_show.groupby('cat').sum(numeric_only=True)

    cat_restante = list(data_show.index)
    col_restante = list(data_show.columns)
    cat_final = []
    col_final = []
    for i in range(len(data_show)):
        i_cat, i_col = get_max_coord(data_show.loc[cat_restante, col_restante])
        n_col, n_cat = col_restante[i_col], cat_restante[i_cat]

        col_final.append(n_col)
        col_restante.remove(n_col)
        cat_final.append(n_cat)
        cat_restante.remove(n_cat)
    
    if return_cat:
        return cat_final, col_final

    print('ARI : ', adjusted_rand_score(original, predict))
    
    return data_show.loc[cat_final, col_final].style.background_gradient(cmap="YlGnBu", axis=0)

# %%
compare_clustering([labels_little[i] for i in y_test_label], pred_test_label)
# Out:
# ARI :  0.6153408456467216
# <style type="text/css">
# #T_03963_row0_col0, #T_03963_row1_col1, #T_03963_row2_col2, #T_03963_row3_col3, #T_03963_row4_col4, #T_03963_row5_col5, #T_03963_row6_col6 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_03963_row0_col1, #T_03963_row0_col2, #T_03963_row0_col3, #T_03963_row0_col4, #T_03963_row0_col5, #T_03963_row0_col6, #T_03963_row1_col0, #T_03963_row1_col4, #T_03963_row1_col5, #T_03963_row2_col1, #T_03963_row2_col4, #T_03963_row2_col6, #T_03963_row3_col0, #T_03963_row4_col0, #T_03963_row4_col1, #T_03963_row4_col2, #T_03963_row4_col3, #T_03963_row5_col0, #T_03963_row6_col0 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_03963_row1_col2 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_03963_row1_col3, #T_03963_row5_col2 {
#   background-color: #f8fcca;
#   color: #000000;
# }
# #T_03963_row1_col6, #T_03963_row3_col6 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# #T_03963_row2_col0 {
#   background-color: #f7fcc6;
#   color: #000000;
# }
# #T_03963_row2_col3, #T_03963_row3_col2, #T_03963_row6_col2 {
#   background-color: #f5fbc2;
#   color: #000000;
# }
# #T_03963_row2_col5 {
#   background-color: #fbfdd0;
#   color: #000000;
# }
# #T_03963_row3_col1, #T_03963_row5_col1 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_03963_row3_col4 {
#   background-color: #f8fcc9;
#   color: #000000;
# }
# #T_03963_row3_col5 {
#   background-color: #f7fcc7;
#   color: #000000;
# }
# #T_03963_row4_col5 {
#   background-color: #c6e9b4;
#   color: #000000;
# }
# #T_03963_row4_col6, #T_03963_row5_col6 {
#   background-color: #f5fbc4;
#   color: #000000;
# }
# #T_03963_row5_col3, #T_03963_row6_col3 {
#   background-color: #fcfed1;
#   color: #000000;
# }
# #T_03963_row5_col4 {
#   background-color: #d5efb3;
#   color: #000000;
# }
# #T_03963_row6_col1 {
#   background-color: #eff9b5;
#   color: #000000;
# }
# #T_03963_row6_col4 {
#   background-color: #f0f9b8;
#   color: #000000;
# }
# #T_03963_row6_col5 {
#   background-color: #e1f3b2;
#   color: #000000;
# }
# </style>
# <table id="T_03963">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03963_level0_col0" class="col_heading level0 col0" >pred_2</th>
#       <th id="T_03963_level0_col1" class="col_heading level0 col1" >pred_4</th>
#       <th id="T_03963_level0_col2" class="col_heading level0 col2" >pred_5</th>
#       <th id="T_03963_level0_col3" class="col_heading level0 col3" >pred_6</th>
#       <th id="T_03963_level0_col4" class="col_heading level0 col4" >pred_0</th>
#       <th id="T_03963_level0_col5" class="col_heading level0 col5" >pred_1</th>
#       <th id="T_03963_level0_col6" class="col_heading level0 col6" >pred_3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cat</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03963_level0_row0" class="row_heading level0 row0" >Watches</th>
#       <td id="T_03963_row0_col0" class="data row0 col0" >49</td>
#       <td id="T_03963_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_03963_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_03963_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_03963_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_03963_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_03963_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_03963_level0_row1" class="row_heading level0 row1" >Kitchen & Dining</th>
#       <td id="T_03963_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_03963_row1_col1" class="data row1 col1" >43</td>
#       <td id="T_03963_row1_col2" class="data row1 col2" >4</td>
#       <td id="T_03963_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_03963_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_03963_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_03963_row1_col6" class="data row1 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_03963_level0_row2" class="row_heading level0 row2" >Beauty and Personal Care</th>
#       <td id="T_03963_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_03963_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_03963_row2_col2" class="data row2 col2" >42</td>
#       <td id="T_03963_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_03963_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_03963_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_03963_row2_col6" class="data row2 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_03963_level0_row3" class="row_heading level0 row3" >Computers</th>
#       <td id="T_03963_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_03963_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_03963_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_03963_row3_col3" class="data row3 col3" >41</td>
#       <td id="T_03963_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_03963_row3_col5" class="data row3 col5" >2</td>
#       <td id="T_03963_row3_col6" class="data row3 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_03963_level0_row4" class="row_heading level0 row4" >Home Furnishing</th>
#       <td id="T_03963_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_03963_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_03963_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_03963_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_03963_row4_col4" class="data row4 col4" >39</td>
#       <td id="T_03963_row4_col5" class="data row4 col5" >9</td>
#       <td id="T_03963_row4_col6" class="data row4 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_03963_level0_row5" class="row_heading level0 row5" >Baby Care</th>
#       <td id="T_03963_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_03963_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_03963_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_03963_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_03963_row5_col4" class="data row5 col4" >8</td>
#       <td id="T_03963_row5_col5" class="data row5 col5" >36</td>
#       <td id="T_03963_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_03963_level0_row6" class="row_heading level0 row6" >Home Decor & Festive Needs</th>
#       <td id="T_03963_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_03963_row6_col1" class="data row6 col1" >5</td>
#       <td id="T_03963_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_03963_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_03963_row6_col4" class="data row6 col4" >4</td>
#       <td id="T_03963_row6_col5" class="data row6 col5" >6</td>
#       <td id="T_03963_row6_col6" class="data row6 col6" >30</td>
#     </tr>
#   </tbody>
# </table>

# %%
list_cat, list_col = compare_clustering([labels_little[i] for i in y_test_label], pred_test_label, True)

# %%
tmp = pd.DataFrame()

# %%
tmp['label'] = [labels_little[i] for i in y_test_label]
tmp['pred'] = [labels_little[i] for i in pred_test_label]

# %%
@interact
def show_img(reel=list_cat, predit=list_cat, index=range(0, 10)):
    
    l = list(tmp.loc[(tmp['label']==reel) & (tmp['pred']==predit)].index)
    
    print("Nombre de lignes : ", len(l))
    if index >= len(l):
        return None

    print("Index de cette image dans tmp : ", l[index])
    
    img = cv2.imread(X_test_img.iloc[l[index]])
    h, w = img.shape[:2]
    aspect = h/w
    img = cv2.resize(img, dsize=(400, int(400*aspect)), interpolation=cv2.INTER_CUBIC)
    return show_from_cv2(img)
# Out:
# interactive(children=(Dropdown(description='reel', options=('Watches', 'Kitchen & Dining', 'Beauty and Persona…
